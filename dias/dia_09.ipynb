# %%
# installar matplotlib
# pip install matplotlib
# importar matplotlib
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,5,30]
plt.bar(x,y)
plt.title("Ejemplo de grafico")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.show()

# plt.plot() - linea
#plt.bar() - barras
#plt.scatter() - dispersion
#plt.hist() - histograma
#plt.pie() - pastel

# %%
# instalar seaborn
# pip install seaborn
# inportar
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")

sns.scatterplot(x="day", y="total_bill", data=tips)
plt.title("cuenta total por dia")
plt.show()

# tipos de graficas
#sns.barplot() - barra
#sns.histplot() - histograma
#sns.scatterplot() - dispersion
#sns.boxplot() - caja
#sns.heatmap() - mapa de calor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

# Mapa de calor de correlaciones
correlation = tips.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlación entre variables")
plt.show()
